# %%
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ### Importing the Email Addresses list

# %%
df = pd.read_excel("Email List.xlsx") 
auto_excel_df = pd.read_excel("Automating Excel Sheet.xlsx")

# %%
df
# Out:
#                               email     contact
# 0       220160212105.simra@gdgu.org  8076406782
# 1     210160203057.sourabh@gdgu.org  8222812374
# 2      211160203002.ishant@gdgu.org  9582046255
# 3       221160201001.mohit@gdgu.org  8295285643
# 4      200020223020.vijeet@gdgu.org  9050420318
# ..                              ...         ...
# 559     230160307024.pawan@gdgu.org  8802430577
# 560     210160204006.mohit@gdgu.org  7678173243
# 561  230160203049.padmanav@gdgu.org  9127422310
# 562     chetankumarpiw100@gmail.com  8586944204
# 563     210160004001.wasim@gdgu.org  9773521083
#
# [564 rows x 2 columns]

# %%
df.dropna(inplace= True)

# %%
df
# Out:
#                               email     contact
# 0       220160212105.simra@gdgu.org  8076406782
# 1     210160203057.sourabh@gdgu.org  8222812374
# 2      211160203002.ishant@gdgu.org  9582046255
# 3       221160201001.mohit@gdgu.org  8295285643
# 4      200020223020.vijeet@gdgu.org  9050420318
# ..                              ...         ...
# 559     230160307024.pawan@gdgu.org  8802430577
# 560     210160204006.mohit@gdgu.org  7678173243
# 561  230160203049.padmanav@gdgu.org  9127422310
# 562     chetankumarpiw100@gmail.com  8586944204
# 563     210160004001.wasim@gdgu.org  9773521083
#
# [564 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# 66

# %%
df.drop_duplicates(inplace= True)

# %%
df.reset_index(inplace= True, drop= True )

# %%
df.isna().sum()
# Out:
# email      0
# contact    0
# dtype: int64

# %%
df
# Out:
#                               email     contact
# 0       220160212105.simra@gdgu.org  8076406782
# 1     210160203057.sourabh@gdgu.org  8222812374
# 2      211160203002.ishant@gdgu.org  9582046255
# 3       221160201001.mohit@gdgu.org  8295285643
# 4      200020223020.vijeet@gdgu.org  9050420318
# ..                              ...         ...
# 493     230160307024.pawan@gdgu.org  8802430577
# 494     210160204006.mohit@gdgu.org  7678173243
# 495  230160203049.padmanav@gdgu.org  9127422310
# 496     chetankumarpiw100@gmail.com  8586944204
# 497     210160004001.wasim@gdgu.org  9773521083
#
# [498 rows x 2 columns]

# %%
# Code to generate Random Indian Numbers

# # Creating 180 Random Indian Numbers

# numbers = []

# for i in range(180):
#     # Creating first 2 digits of Indian Numbers

#     num_first_2 = np.array(["99", "83", "74", "85", "96", "87", "79", "90", "70", "98", "82"]) # Random number will be chosen from this list for the 
#                                                                                                # first 2 digits of the numbers
    
#     # Generating next 4 random digits of the Indian Numbers
    
#     num_mid_4 = np.random.randint(1111, 9999) # It will randomly choose numbers form the given range
#     num_mid_4 = str(num_mid_4)  # Converting the numbers to string for concatinating
    
#     # Generating last 4 random digits of the Indian Numbers
    
#     num_last_4 = np.random.randint(1111, 9999) # It will randomly choose numbers form the given range
#     num_last_4 = str(num_last_4)

#     # Merging and appending the numbers in the numbers list
#     numbers.append(np.random.choice(num_first_2) + num_mid_4 + num_last_4)

# %%
df
# Out:
#                               email     contact
# 0       220160212105.simra@gdgu.org  8076406782
# 1     210160203057.sourabh@gdgu.org  8222812374
# 2      211160203002.ishant@gdgu.org  9582046255
# 3       221160201001.mohit@gdgu.org  8295285643
# 4      200020223020.vijeet@gdgu.org  9050420318
# ..                              ...         ...
# 493     230160307024.pawan@gdgu.org  8802430577
# 494     210160204006.mohit@gdgu.org  7678173243
# 495  230160203049.padmanav@gdgu.org  9127422310
# 496     chetankumarpiw100@gmail.com  8586944204
# 497     210160004001.wasim@gdgu.org  9773521083
#
# [498 rows x 2 columns]

# %%
auto_excel_df
# Out:
#                      Page No.  \
# 0  formResponse?pageHistory=0
# 1                         NaN
# 2                         NaN
#
#                                           Final Link  \
# 0  https://docs.google.com/forms/d/e/1FAIpQLSc2Rh...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Link  \
# 0  https://docs.google.com/forms/d/e/1FAIpQLSc2Rh...
# 1                                                NaN
# 2                                                NaN
#
#                           Email Response              Contact Response  \
# 0   emailAddress=noname7231236@gmail.com   entry.1585933220=9912546853
# 1                                    NaN                           NaN
# 2  emailAddress="noname7231236@gmail.com  entry.1585933220="9912546853
#
#        Are you a Gamer?        What Type of Gamer?  \
# 0   entry.1534863658=Yes       entry.1274209221=PC
# ...

# %% [markdown]
# ## Here the entry values are added to tell where the values need to be filled and you can find that, by following steps:
#
# * Open Google Forms
# * Fill the Form but don't submit yet.
# * Not right click on the forms and open Inspect menu.
# * Now you have to press **CTRL + F** in the inspect menu.
# * Now type **entry.**
# * You will find the values you entered in the form and then copy those lines, by right clicking on it and then **copy -> Copy Element**
# * Now paste those values in a excel file and then clean the data and try to make it like my excel file named **Automating Excel Sheet.xlsx**
# * You can watch this video for more reference **https://youtu.be/A7U_CyhHLg8?si=aw1V42FYY9K8ulYN**
#
#
#
#   ![image.png](attachment:d1402eb9-bc7a-43ee-ab18-1fcb5c039ce7.png)

# %% [markdown]
# ### Adding Program School Name

# %%
program_school_name = ["SoME", "SOES", "SOM", "SoAS", "SOL"]

schools_lst = []
for i in range(498):
    schools_lst.append("entry.767675694=" + np.random.choice(program_school_name))

schools_lst
# Out:
# ['entry.767675694=SoAS',
#  'entry.767675694=SOES',
#  'entry.767675694=SOES',
#  'entry.767675694=SOL',
#  'entry.767675694=SoAS',
#  'entry.767675694=SoAS',
#  'entry.767675694=SOL',
#  'entry.767675694=SOL',
#  'entry.767675694=SOES',
#  'entry.767675694=SOL',
#  'entry.767675694=SOM',
#  'entry.767675694=SoME',
#  'entry.767675694=SoME',
#  'entry.767675694=SOM',
#  'entry.767675694=SOL',
#  'entry.767675694=SOES',
#  'entry.767675694=SoME',
#  'entry.767675694=SOL',
#  'entry.767675694=SoME',
#  'entry.767675694=SOES',
#  'entry.767675694=SoAS',
#  'entry.767675694=SoME',
#  'entry.767675694=SoME',
#  'entry.767675694=SoAS',
#  'entry.767675694=SOL',
#  'entry.767675694=SoAS',
#  'entry.767675694=SoME',
#  'entry.767675694=SOL',
#  'entry.767675694=SOL',
#  'entry.767675694=SoME',
#  'entry.767675694=SOM',
#  'entry.767675694=SOES',
#  'entry.767675694=SOL',
#  'entry.767675694=SOL',
#  'entry.767675694=SoAS',
#  'entry.767675694=SOES',
#  'entry.767675694=SOES',
# ...

# %% [markdown]
# ### Are you a Gamer?

# %%
areYouAGamer = ["Yes", "No"]

areYouAGamer_lst = []
for i in range(498):
    areYouAGamer_lst.append("entry.1534863658=" + np.random.choice(areYouAGamer, p = [0.4, 0.6]))

areYouAGamer_lst
# Out:
# ['entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=Yes',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=Yes',
#  'entry.1534863658=Yes',
#  'entry.1534863658=Yes',
#  'entry.1534863658=No',
#  'entry.1534863658=Yes',
#  'entry.1534863658=Yes',
#  'entry.1534863658=No',
#  'entry.1534863658=Yes',
#  'entry.1534863658=Yes',
#  'entry.1534863658=Yes',
#  'entry.1534863658=Yes',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=Yes',
#  'entry.1534863658=Yes',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=Yes',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=No',
#  'entry.1534863658=Yes',
#  'entry.1534863658=No',
#  'entry.1534863658=Yes',
#  'entry.1534863658=No',
#  'entry.1534863658=Yes',
#  'entry.1534863658=Yes',
# ...

# %% [markdown]
# ### What Type of Gamer?

# %%
whatTypeOfGamer = ["PC", "Mobile", "Console"]

whatTypeOfGamer_lst = []
for i in range(498):
    whatTypeOfGamer_lst.append("entry.1274209221=" + np.random.choice(whatTypeOfGamer, p = [0.3, 0.4, 0.3]))

whatTypeOfGamer_lst
# Out:
# ['entry.1274209221=Console',
#  'entry.1274209221=PC',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Console',
#  'entry.1274209221=PC',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Console',
#  'entry.1274209221=PC',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Console',
#  'entry.1274209221=Console',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=PC',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=PC',
#  'entry.1274209221=PC',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Console',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=PC',
#  'entry.1274209221=PC',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=Mobile',
#  'entry.1274209221=PC',
#  'entry.1274209221=PC',
#  'entry.1274209221=Console',
#  'entry.1274209221=PC',
#  'entry.1274209221=Console',
#  'entry.1274209221=Console',
# ...

# %% [markdown]
# ### Which Game to play in Experience Zone ?

# %%
gameToPlayInExperienceZone = ["VR", "Play station", "Lan Gaming"]

gameToPlayInExperienceZone_lst = []
for i in range(498):
    gameToPlayInExperienceZone_lst.append("entry.759405699=" + np.random.choice(gameToPlayInExperienceZone, p = [0.5, 0.25, 0.25]))

gameToPlayInExperienceZone_lst
# Out:
# ['entry.759405699=Play station',
#  'entry.759405699=Lan Gaming',
#  'entry.759405699=VR',
#  'entry.759405699=VR',
#  'entry.759405699=Lan Gaming',
#  'entry.759405699=VR',
#  'entry.759405699=VR',
#  'entry.759405699=Lan Gaming',
#  'entry.759405699=VR',
#  'entry.759405699=VR',
#  'entry.759405699=Play station',
#  'entry.759405699=VR',
#  'entry.759405699=Lan Gaming',
#  'entry.759405699=VR',
#  'entry.759405699=VR',
#  'entry.759405699=VR',
#  'entry.759405699=VR',
#  'entry.759405699=Lan Gaming',
#  'entry.759405699=Lan Gaming',
#  'entry.759405699=VR',
#  'entry.759405699=Play station',
#  'entry.759405699=Play station',
#  'entry.759405699=VR',
#  'entry.759405699=Play station',
#  'entry.759405699=Play station',
#  'entry.759405699=VR',
#  'entry.759405699=VR',
#  'entry.759405699=Lan Gaming',
#  'entry.759405699=VR',
#  'entry.759405699=Lan Gaming',
#  'entry.759405699=VR',
#  'entry.759405699=VR',
#  'entry.759405699=Lan Gaming',
#  'entry.759405699=Lan Gaming',
# ...

# %%
auto_excel_df
# Out:
#                      Page No.  \
# 0  formResponse?pageHistory=0
# 1                         NaN
# 2                         NaN
#
#                                           Final Link  \
# 0  https://docs.google.com/forms/d/e/1FAIpQLSc2Rh...
# 1                                                NaN
# 2                                                NaN
#
#                                                 Link  \
# 0  https://docs.google.com/forms/d/e/1FAIpQLSc2Rh...
# 1                                                NaN
# 2                                                NaN
#
#                           Email Response              Contact Response  \
# 0   emailAddress=noname7231236@gmail.com   entry.1585933220=9912546853
# 1                                    NaN                           NaN
# 2  emailAddress="noname7231236@gmail.com  entry.1585933220="9912546853
#
#        Are you a Gamer?        What Type of Gamer?  \
# 0   entry.1534863658=Yes       entry.1274209221=PC
# ...

# %%
df.head(1)
# Out:
#                          email     contact
# 0  220160212105.simra@gdgu.org  8076406782

# %% [markdown]
# ### Correcting Email Format as per Automating Df

# %%
df["email"] = df["email"].apply(lambda x: "emailAddress=" + x)

# %% [markdown]
# ### Correcting Contact Format as per Automating Df

# %%
# Converting contact column to int datatype

df["contact"] = df["contact"].astype("str")

df["contact"] = df["contact"].apply(lambda x: "entry.1585933220=" + x)

# %% [markdown]
# ### Adding Other Data to the Column

# %%
df["Are you a Gamer?"] = areYouAGamer_lst
df["What Type of Gamer?"] = whatTypeOfGamer_lst
df["Choose game to play in Experience Zone"] = gameToPlayInExperienceZone_lst
df["School Name"] = schools_lst

# %%
df.sample(5)
# Out:
#                                            email                      contact  \
# 479         emailAddress=guptaprity673@gmail.com  entry.1585933220=8287606079
# 228         emailAddress=amangupta2875@gmail.com  entry.1585933220=9871181435
# 305      emailAddress=vihamalhotra2004@gmail.com  entry.1585933220=9650745716
# 304  emailAddress=230160223010.devanshu@gdgu.org  entry.1585933220=8178461491
# 353              emailAddress=dikxgo18@gmail.com  entry.1585933220=8638278356
#
#          Are you a Gamer?      What Type of Gamer?  \
# 479  entry.1534863658=Yes  entry.1274209221=Mobile
# 228   entry.1534863658=No  entry.1274209221=Mobile
# 305  entry.1534863658=Yes      entry.1274209221=PC
# 304  entry.1534863658=Yes  entry.1274209221=Mobile
# 353  entry.1534863658=Yes  entry.1274209221=Mobile
#
#     Choose game to play in Experience Zone           School Name
# 479                     entry.759405699=VR  entry.767675694=SoAS
# ...

# %%
auto_excel_df["Link"][0]
# Out:
# 'https://docs.google.com/forms/d/e/1FAIpQLSc2RhbqWwvm_GjgFYNj1jhtFS6eezkCHdMRqPQmZz730INB-Q/formResponse?pageHistory=0&emailAddress=noname7231236@gmail.com&entry.1585933220=9912546853&entry.1534863658=Yes&entry.1274209221=PC&entry.759405699=VR&entry.767675694=SOME'

# %%
url = "https://docs.google.com/forms/d/e/1FAIpQLSc2RhbqWwvm_GjgFYNj1jhtFS6eezkCHdMRqPQmZz730INB-Q/formResponse?pageHistory=0&"  # My sample testing URL
df["url"] = url

# %%
df.sample()
# Out:
#                                          email                      contact  \
# 134  emailAddress=220160203069.vishal@gdgu.org  entry.1585933220=8708753921
#
#         Are you a Gamer?      What Type of Gamer?  \
# 134  entry.1534863658=No  entry.1274209221=Mobile
#
#     Choose game to play in Experience Zone           School Name  \
# 134             entry.759405699=Lan Gaming  entry.767675694=SOES
#
#                                                    url
# 134  https://docs.google.com/forms/d/e/1FAIpQLSc2Rh...

# %%
auto_excel_df["Final Link"][0]
# Out:
# 'https://docs.google.com/forms/d/e/1FAIpQLSc2RhbqWwvm_GjgFYNj1jhtFS6eezkCHdMRqPQmZz730INB-Q/formResponse?pageHistory=0&emailAddress=diwakanihsikjhfshiukjhfisjhfsi7231236@gmail.com&entry.1585933220=9912546853&entry.1534863658=Yes&entry.1274209221=PC&entry.759405699=VR&entry.767675694=SOES'

# %%
df["automateFinalURL"] = df["url"] + df["email"] + "&" + df["contact"] + "&" + df["Are you a Gamer?"] + "&" + df["What Type of Gamer?"] + "&" + df["Choose game to play in Experience Zone"] + "&" + df["School Name"]

# %% [markdown]
# ### Autofilling the Exeperince Zone Responses

# %%
for url in df["automateFinalURL"]:
    requests.get(url)

# %%
# df["automateFinalURL"][0]
